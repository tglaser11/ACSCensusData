# %%
import pandas as pd

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('dppruned.csv')
# Out:
# /home/tom/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (62,63,64,65,66,67,68,69,259,290,293,295,296,297,316,361,366,367,399) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
plt.figure();
df['Estimate; HOUSEHOLDS BY TYPE - Total households'].plot.hist(bins=200)

# %%
# df['Percent; HOUSEHOLDS BY TYPE - Total households - Family households (families)'] = df['Percent; HOUSEHOLDS BY TYPE - Total households - Family households (families)'].str.replace('-','0')
# df['Percent; HOUSEHOLDS BY TYPE - Total households - Family households (families)'] = df['Percent; HOUSEHOLDS BY TYPE - Total households - Family households (families)'].astype(float)
df['Percent; HOUSEHOLDS BY TYPE - Total households - Family households (families)'].plot.hist(bins=20)

# %%
df['Estimate; HOUSEHOLDS BY TYPE - Total households - Family households (families) - With own children of the householder under 18 years'].plot.hist(bins=200)

# %%
df['Percent; HOUSEHOLDS BY TYPE - Total households - Family households (families) - With own children of the householder under 18 years'].plot.hist(bins=20)

# %%
df['Estimate; HOUSEHOLDS BY TYPE - Total households - Family households (families) - Married-couple family'].plot.hist(bins=200)

# %%
df['Percent; HOUSEHOLDS BY TYPE - Total households - Family households (families) - Married-couple family'].plot.hist(bins=20)

# %%
df['Percent; HOUSEHOLDS BY TYPE - Total households - Family households (families) - Married-couple family - With own children of the householder under 18 years'].plot.hist(bins=20)

# %%
df['Percent; HOUSEHOLDS BY TYPE - Total households - Family households (families) - Male householder, no wife present, family'].plot.hist(bins=20)

# %%
df['Percent; HOUSEHOLDS BY TYPE - Total households - Family households (families) - Male householder, no wife present, family - With own children of the householder under 18 years'].plot.hist(bins=20)

# %%
df['Percent; HOUSEHOLDS BY TYPE - Total households - Family households (families) - Female householder, no husband present, family'].plot.hist(bins=20)

# %%
df['Percent; HOUSEHOLDS BY TYPE - Total households - Family households (families) - Female householder, no husband present, family - With own children of the householder under 18 years'].plot.hist(bins=20)

# %%
df['Percent; HOUSEHOLDS BY TYPE - Total households - Nonfamily households'].plot.hist(bins=20)

# %%
df['Percent; HOUSEHOLDS BY TYPE - Total households - Nonfamily households - Householder living alone'].plot.hist(bins=20)

# %%
df['Percent; HOUSEHOLDS BY TYPE - Total households - Nonfamily households - Householder living alone - 65 years and over'].plot.hist(bins=20)

# %%
df['Percent; HOUSEHOLDS BY TYPE - Households with one or more people under 18 years'].plot.hist(bins=20)

# %%
df['Percent; HOUSEHOLDS BY TYPE - Households with one or more people 65 years and over'].plot.hist(bins=20)

# %%
df['Estimate; HOUSEHOLDS BY TYPE - Average household size'].plot.hist(bins=20)

# %%
df['Estimate; HOUSEHOLDS BY TYPE - Average family size'].plot.hist(bins=20)

# %%
df['Percent; MARITAL STATUS - Males 15 years and over - Never married'].plot.hist(bins=20)

# %%
df['Percent; MARITAL STATUS - Males 15 years and over - Now married, except separated'].plot.hist(bins=20)

# %%
df['Percent; MARITAL STATUS - Males 15 years and over - Separated'].plot.hist(bins=20)

# %%
df['Percent; MARITAL STATUS - Males 15 years and over - Widowed'].plot.hist(bins=20)

# %%
df['Percent; MARITAL STATUS - Males 15 years and over - Divorced'].plot.hist(bins=20)

# %%
df['Percent; MARITAL STATUS - Females 15 years and over - Never married'].plot.hist(bins=20)

# %%
df['Percent; MARITAL STATUS - Females 15 years and over - Now married, except separated'].plot.hist(bins=20)

# %%
df['Percent; MARITAL STATUS - Females 15 years and over - Separated'].plot.hist(bins=20)

# %%
df['Percent; MARITAL STATUS - Females 15 years and over - Widowed'].plot.hist(bins=20)

# %%
df['Percent; MARITAL STATUS - Females 15 years and over - Divorced'].plot.hist(bins=20)

# %%
df['Percent; SCHOOL ENROLLMENT - Population 3 years and over enrolled in school - Nursery school, preschool'].plot.hist(bins=20)

# %%
df['Percent; SCHOOL ENROLLMENT - Population 3 years and over enrolled in school - Kindergarten'].plot.hist(bins=20)

# %%
df['Percent; SCHOOL ENROLLMENT - Population 3 years and over enrolled in school - Elementary school (grades 1-8)'].plot.hist(bins=20)

# %%
df['Percent; SCHOOL ENROLLMENT - Population 3 years and over enrolled in school - High school (grades 9-12)'].plot.hist(bins=20)

# %%
df['Percent; SCHOOL ENROLLMENT - Population 3 years and over enrolled in school - College or graduate school'].plot.hist(bins=20)

# %%
df['Percent; EDUCATIONAL ATTAINMENT - Population 25 years and over - Less than 9th grade'].plot.hist(bins=20)

# %%
df['Percent; EDUCATIONAL ATTAINMENT - Population 25 years and over - 9th to 12th grade, no diploma'].plot.hist(bins=20)

# %%
df['Percent; EDUCATIONAL ATTAINMENT - Population 25 years and over - High school graduate (includes equivalency)'].plot.hist(bins=20)

# %%
df['Percent; EDUCATIONAL ATTAINMENT - Population 25 years and over - Some college, no degree'].plot.hist(bins=20)

# %%
df['Percent; EDUCATIONAL ATTAINMENT - Population 25 years and over - Associate\'s degree'].plot.hist(bins=20)

# %%
df['Percent; EDUCATIONAL ATTAINMENT - Population 25 years and over - Bachelor\'s degree'].plot.hist(bins=20)

# %%
df['Percent; EDUCATIONAL ATTAINMENT - Population 25 years and over - Graduate or professional degree'].plot.hist(bins=20)

# %%
df['Percent; VETERAN STATUS - Civilian population 18 years and over - Civilian veterans'].plot.hist(bins=20)

# %%
df['Percent; DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION - Total Civilian Noninstitutionalized Population - With a disability'].plot.hist(bins=20)

# %%
df['Percent; RESIDENCE 1 YEAR AGO - Population 1 year and over - Same house'].plot.hist(bins=20)

# %%
df['Percent; RESIDENCE 1 YEAR AGO - Population 1 year and over - Different house in the U.S.'].plot.hist(bins=20)

# %%
df['Percent; RESIDENCE 1 YEAR AGO - Population 1 year and over - Different house in the U.S. - Different county'].plot.hist(bins=20)

# %%
df['Percent; RESIDENCE 1 YEAR AGO - Population 1 year and over - Different house in the U.S. - Different county'].plot.hist(bins=20)

# %%
df['Percent; PLACE OF BIRTH - Total population - Native - Born in United States'].plot.hist(bins=20)

# %%
df['Percent; PLACE OF BIRTH - Total population - Native - Born in United States - State of residence'].plot.hist(bins=20)

# %%
df['Percent; LANGUAGE SPOKEN AT HOME - Population 5 years and over - English only'].plot.hist(bins=20)

# %%
df['Percent; ANCESTRY - Total population - American'].plot.hist(bins=20)

# %%
df['Percent; ANCESTRY - Total population - Arab'].plot.hist(bins=20)

# %%
df['Percent; ANCESTRY - Total population - Czech'].plot.hist(bins=20)

# %%
df['Percent; ANCESTRY - Total population - Danish'].plot.hist(bins=20)

# %%
df['Percent; ANCESTRY - Total population - Dutch'].plot.hist(bins=20)

# %%
df['Percent; ANCESTRY - Total population - English'].plot.hist(bins=20)

# %%
df['Percent; ANCESTRY - Total population - French (except Basque)'].plot.hist(bins=20)

# %%
df['Percent; ANCESTRY - Total population - French Canadian'].plot.hist(bins=20)

# %%
df['Percent; ANCESTRY - Total population - German'].plot.hist(bins=20)

# %%
df['Percent; ANCESTRY - Total population - Greek'].plot.hist(bins=20)

# %%
df['Percent; ANCESTRY - Total population - Hungarian'].plot.hist(bins=20)

# %%
df['Percent; ANCESTRY - Total population - Irish'].plot.hist(bins=20)

# %%
df['Percent; ANCESTRY - Total population - Italian'].plot.hist(bins=20)

# %%
df['Percent; ANCESTRY - Total population - Lithuanian'].plot.hist(bins=20)

# %%
df['Percent; ANCESTRY - Total population - Norwegian'].plot.hist(bins=20)

# %%
df['Percent; ANCESTRY - Total population - Polish'].plot.hist(bins=20)

# %%
df['Percent; ANCESTRY - Total population - Portuguese'].plot.hist(bins=20)

# %%
df['Percent; ANCESTRY - Total population - Russian'].plot.hist(bins=20)

# %%
df['Percent; ANCESTRY - Total population - Scotch-Irish'].plot.hist(bins=20)

# %%
df['Percent; ANCESTRY - Total population - Scottish'].plot.hist(bins=20)

# %%
df['Percent; ANCESTRY - Total population - Slovak'].plot.hist(bins=20)

# %%
df['Percent; ANCESTRY - Total population - Subsaharan African'].plot.hist(bins=20)

# %%
df['Percent; ANCESTRY - Total population - Swedish'].plot.hist(bins=20)

# %%
df['Percent; ANCESTRY - Total population - Swiss'].plot.hist(bins=20)

# %%
df['Percent; ANCESTRY - Total population - Ukrainian'].plot.hist(bins=20)

# %%
df['Percent; ANCESTRY - Total population - Welsh'].plot.hist(bins=20)

# %%
df['Percent; ANCESTRY - Total population - West Indian (excluding Hispanic origin groups)'].plot.hist(bins=20)

# %%
df['Percent; EMPLOYMENT STATUS - Population 16 years and over - In labor force'].plot.hist(bins=20)

# %%
df['Percent; EMPLOYMENT STATUS - Civilian labor force - Unemployment Rate'].plot.hist(bins=20)

# %%
df['Percent; EMPLOYMENT STATUS - Females 16 years and over - In labor force'].plot.hist(bins=20)

# %%
df['Percent; COMMUTING TO WORK - Workers 16 years and over - Car, truck, or van -- drove alone'].plot.hist(bins=20)

# %%
df['Percent; COMMUTING TO WORK - Workers 16 years and over - Car, truck, or van -- carpooled'].plot.hist(bins=20)

# %%
df['Percent; COMMUTING TO WORK - Workers 16 years and over - Public transportation (excluding taxicab)'].plot.hist(bins=20)

# %%
df['Percent; COMMUTING TO WORK - Workers 16 years and over - Walked'].plot.hist(bins=20)

# %%
df['Percent; COMMUTING TO WORK - Workers 16 years and over - Other means'].plot.hist(bins=20)

# %%
df['Percent; COMMUTING TO WORK - Workers 16 years and over - Worked at home'].plot.hist(bins=20)

# %%
df['Percent; OCCUPATION - Civilian employed population 16 years and over - Management, business, science, and arts occupations'].plot.hist(bins=20)

# %%
df['Percent; OCCUPATION - Civilian employed population 16 years and over - Service occupations'].plot.hist(bins=20)

# %%
df['Percent; OCCUPATION - Civilian employed population 16 years and over - Sales and office occupations'].plot.hist(bins=20)

# %%
df['Percent; OCCUPATION - Civilian employed population 16 years and over - Natural resources, construction, and maintenance occupations'].plot.hist(bins=20)

# %%
df['Percent; OCCUPATION - Civilian employed population 16 years and over - Production, transportation, and material moving occupations'].plot.hist(bins=20)

# %%
df['Percent; INDUSTRY - Civilian employed population 16 years and over - Agriculture, forestry, fishing and hunting, and mining'].plot.hist(bins=20)

# %%
df['Percent; INDUSTRY - Civilian employed population 16 years and over - Construction'].plot.hist(bins=20)

# %%
df['Percent; INDUSTRY - Civilian employed population 16 years and over - Manufacturing'].plot.hist(bins=20)

# %%
df['Percent; INDUSTRY - Civilian employed population 16 years and over - Wholesale trade'].plot.hist(bins=20)

# %%
df['Percent; INDUSTRY - Civilian employed population 16 years and over - Retail trade'].plot.hist(bins=20)

# %%
df['Percent; INDUSTRY - Civilian employed population 16 years and over - Transportation and warehousing, and utilities'].plot.hist(bins=20)

# %%
df['Percent; INDUSTRY - Civilian employed population 16 years and over - Information'].plot.hist(bins=20)

# %%
df['Percent; INDUSTRY - Civilian employed population 16 years and over - Finance and insurance, and real estate and rental and leasing'].plot.hist(bins=20)

# %%
df['Percent; INDUSTRY - Civilian employed population 16 years and over - Professional, scientific, and management, and administrative and waste management services'].plot.hist(bins=20)

# %%
df['Percent; INDUSTRY - Civilian employed population 16 years and over - Educational services, and health care and social assistance'].plot.hist(bins=20)

# %%
df['Percent; INDUSTRY - Civilian employed population 16 years and over - Arts, entertainment, and recreation, and accommodation and food services'].plot.hist(bins=20)

# %%
df['Percent; INDUSTRY - Civilian employed population 16 years and over - Other services, except public administration'].plot.hist(bins=20)

# %%
df['Percent; INDUSTRY - Civilian employed population 16 years and over - Public administration'].plot.hist(bins=20)

# %%
df['Percent; CLASS OF WORKER - Civilian employed population 16 years and over - Private wage and salary workers'].plot.hist(bins=20)

# %%
df['Percent; CLASS OF WORKER - Civilian employed population 16 years and over - Government workers'].plot.hist(bins=20)

# %%
df['Percent; CLASS OF WORKER - Civilian employed population 16 years and over - Self-employed in own not incorporated business workers'].plot.hist(bins=20)

# %%
df['Percent; CLASS OF WORKER - Civilian employed population 16 years and over - Unpaid family workers'].plot.hist(bins=20)

# %%
df['Percent; INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTED DOLLARS) - Total households - Less than $10,000'].plot.hist(bins=20)

# %%
df['Percent; INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTED DOLLARS) - Total households - $10,000 to $14,999'].plot.hist(bins=20)

# %%
df['Percent; INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTED DOLLARS) - Total households - $15,000 to $24,999'].plot.hist(bins=20)

# %%
df['Percent; INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTED DOLLARS) - Total households - $25,000 to $34,999'].plot.hist(bins=20)

# %%
df['Percent; INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTED DOLLARS) - Total households - $35,000 to $49,999'].plot.hist(bins=20)

# %%
df['Percent; INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTED DOLLARS) - Total households - $50,000 to $74,999'].plot.hist(bins=20)

# %%
df['Percent; INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTED DOLLARS) - Total households - $75,000 to $99,999'].plot.hist(bins=20)

# %%
df['Percent; INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTED DOLLARS) - Total households - $100,000 to $149,999'].plot.hist(bins=20)

# %%
df['Percent; INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTED DOLLARS) - Total households - $150,000 to $199,999'].plot.hist(bins=20)

# %%
df['Percent; INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTED DOLLARS) - Total households - $200,000 or more'].plot.hist(bins=20)

# %%
df['Percent; INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTED DOLLARS) - With Social Security'].plot.hist(bins=20)

# %%
df['Percent; INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTED DOLLARS) - With retirement income'].plot.hist(bins=20)

# %%
df['Percent; INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTED DOLLARS) - Families - Less than $10,000'].plot.hist(bins=20)

# %%
df['Percent; INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTED DOLLARS) - Families - $10,000 to $14,999'].plot.hist(bins=20)

# %%
df['Percent; INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTED DOLLARS) - Families - $15,000 to $24,999'].plot.hist(bins=20)

# %%
df['Percent; INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTED DOLLARS) - Families - $25,000 to $34,999'].plot.hist(bins=20)

# %%
df['Percent; INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTED DOLLARS) - Families - $35,000 to $49,999'].plot.hist(bins=20)

# %%
df['Percent; INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTED DOLLARS) - Families - $50,000 to $74,999'].plot.hist(bins=20)

# %%
df['Percent; INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTED DOLLARS) - Families - $75,000 to $99,999'].plot.hist(bins=20)

# %%
df['Percent; INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTED DOLLARS) - Families - $100,000 to $149,999'].plot.hist(bins=20)

# %%
df['Percent; INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTED DOLLARS) - Families - $150,000 to $199,999'].plot.hist(bins=20)

# %%
df['Percent; INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTED DOLLARS) - Families - $200,000 or more'].plot.hist(bins=20)

# %%
df['Percent; HEALTH INSURANCE COVERAGE - Civilian noninstitutionalized population - With health insurance coverage'].plot.hist(bins=20)

# %%
df['Percent; HEALTH INSURANCE COVERAGE - Civilian noninstitutionalized population - With health insurance coverage - With private health insurance'].plot.hist(bins=20)

# %%
df['Percent; HEALTH INSURANCE COVERAGE - Civilian noninstitutionalized population - With health insurance coverage - With public coverage'].plot.hist(bins=20)

# %%
df['Percent; HEALTH INSURANCE COVERAGE - Civilian noninstitutionalized population - No health insurance coverage'].plot.hist(bins=20)

# %%
df['Percent; PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL - All families'].plot.hist(bins=20)

# %%
df['Percent; HOUSING OCCUPANCY - Total housing units - Occupied housing units'].plot.hist(bins=20)

# %%
df['Percent; YEAR STRUCTURE BUILT - Total housing units - Built 2014 or later'].plot.hist(bins=20)

# %%
df['Percent; YEAR STRUCTURE BUILT - Total housing units - Built 2010 to 2013'].plot.hist(bins=20)

# %%
df['Percent; YEAR STRUCTURE BUILT - Total housing units - Built 2000 to 2009'].plot.hist(bins=20)

# %%
df['Percent; YEAR STRUCTURE BUILT - Total housing units - Built 1990 to 1999'].plot.hist(bins=20)

# %%
df['Percent; YEAR STRUCTURE BUILT - Total housing units - Built 1980 to 1989'].plot.hist(bins=20)

# %%
df['Percent; YEAR STRUCTURE BUILT - Total housing units - Built 1970 to 1979'].plot.hist(bins=20)

# %%
df['Percent; YEAR STRUCTURE BUILT - Total housing units - Built 1960 to 1969'].plot.hist(bins=20)

# %%
df['Percent; YEAR STRUCTURE BUILT - Total housing units - Built 1950 to 1959'].plot.hist(bins=20)

# %%
df['Percent; YEAR STRUCTURE BUILT - Total housing units - Built 1940 to 1949'].plot.hist(bins=20)

# %%
df['Percent; YEAR STRUCTURE BUILT - Total housing units - Built 1939 or earlier'].plot.hist(bins=20)

# %%
df['Percent; BEDROOMS - Total housing units - No bedroom'].plot.hist(bins=20)

# %%
df['Percent; BEDROOMS - Total housing units - 1 bedroom'].plot.hist(bins=20)

# %%
df['Percent; BEDROOMS - Total housing units - 2 bedrooms'].plot.hist(bins=20)

# %%
df['Percent; BEDROOMS - Total housing units - 3 bedrooms'].plot.hist(bins=20)

# %%
df['Percent; BEDROOMS - Total housing units - 4 bedrooms'].plot.hist(bins=20)

# %%
df['Percent; BEDROOMS - Total housing units - 5 or more bedrooms'].plot.hist(bins=20)

# %%
df['Percent; HOUSING TENURE - Occupied housing units - Owner-occupied'].plot.hist(bins=20)

# %%
df['Percent; HOUSING TENURE - Occupied housing units - Renter-occupied'].plot.hist(bins=20)

# %%
df['Percent; YEAR HOUSEHOLDER MOVED INTO UNIT - Occupied housing units - Moved in 2015 or later'].plot.hist(bins=20)

# %%
df['Percent; YEAR HOUSEHOLDER MOVED INTO UNIT - Occupied housing units - Moved in 2010 to 2014'].plot.hist(bins=20)

# %%
df['Percent; YEAR HOUSEHOLDER MOVED INTO UNIT - Occupied housing units - Moved in 2000 to 2009'].plot.hist(bins=20)

# %%
df['Percent; YEAR HOUSEHOLDER MOVED INTO UNIT - Occupied housing units - Moved in 1990 to 1999'].plot.hist(bins=20)

# %%
df['Percent; YEAR HOUSEHOLDER MOVED INTO UNIT - Occupied housing units - Moved in 1980 to 1989'].plot.hist(bins=20)

# %%
df['Percent; YEAR HOUSEHOLDER MOVED INTO UNIT - Occupied housing units - Moved in 1979 and earlier'].plot.hist(bins=20)

# %%
df['Percent; VEHICLES AVAILABLE - Occupied housing units - No vehicles available'].plot.hist(bins=20)

# %%
df['Percent; VEHICLES AVAILABLE - Occupied housing units - 1 vehicle available'].plot.hist(bins=20)

# %%
df['Percent; VEHICLES AVAILABLE - Occupied housing units - 2 vehicles available'].plot.hist(bins=20)

# %%
df['Percent; VEHICLES AVAILABLE - Occupied housing units - 3 or more vehicles available'].plot.hist(bins=20)

# %%
df['Percent; VALUE - Owner-occupied units - Less than $50,000'].plot.hist(bins=20)

# %%
df['Percent; VALUE - Owner-occupied units - $50,000 to $99,999'].plot.hist(bins=20)

# %%
df['Percent; VALUE - Owner-occupied units - $100,000 to $149,999'].plot.hist(bins=20)

# %%
df['Percent; VALUE - Owner-occupied units - $150,000 to $199,999'].plot.hist(bins=20)

# %%
df['Percent; VALUE - Owner-occupied units - $200,000 to $299,999'].plot.hist(bins=20)

# %%
df['Percent; VALUE - Owner-occupied units - $300,000 to $499,999'].plot.hist(bins=20)

# %%
df['Percent; VALUE - Owner-occupied units - $500,000 to $999,999'].plot.hist(bins=20)

# %%
df['Percent; VALUE - Owner-occupied units - $1,000,000 or more'].plot.hist(bins=20)

# %%
df['Percent; MORTGAGE STATUS - Owner-occupied units - Housing units with a mortgage'].plot.hist(bins=20)

# %%
df['Percent; MORTGAGE STATUS - Owner-occupied units - Housing units without a mortgage'].plot.hist(bins=20)

# %%
df['Percent; SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI) - Housing units with a mortgage (excluding units where SMOCAPI cannot be computed) - Less than 20.0 percent'].plot.hist(bins=20)

# %%
df['Percent; SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI) - Housing units with a mortgage (excluding units where SMOCAPI cannot be computed) - 20.0 to 24.9 percent'].plot.hist(bins=20)

# %%
df['Percent; SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI) - Housing units with a mortgage (excluding units where SMOCAPI cannot be computed) - 25.0 to 29.9 percent'].plot.hist(bins=20)

# %%
df['Percent; SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI) - Housing units with a mortgage (excluding units where SMOCAPI cannot be computed) - 30.0 to 34.9 percent'].plot.hist(bins=20)

# %%
df['Percent; SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI) - Housing units with a mortgage (excluding units where SMOCAPI cannot be computed) - 35.0 percent or more'].plot.hist(bins=20)

# %%
df['Percent; SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI) - Housing unit without a mortgage (excluding units where SMOCAPI cannot be computed) - Less than 10.0 percent'].plot.hist(bins=20)

# %%
df['Percent; SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI) - Housing unit without a mortgage (excluding units where SMOCAPI cannot be computed) - 10.0 to 14.9 percent'].plot.hist(bins=20)

# %%
df['Percent; SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI) - Housing unit without a mortgage (excluding units where SMOCAPI cannot be computed) - 15.0 to 19.9 percent'].plot.hist(bins=20)

# %%
df['Percent; SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI) - Housing unit without a mortgage (excluding units where SMOCAPI cannot be computed) - 20.0 to 24.9 percent'].plot.hist(bins=20)

# %%
df['Percent; SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI) - Housing unit without a mortgage (excluding units where SMOCAPI cannot be computed) - 25.0 to 29.9 percent'].plot.hist(bins=20)

# %%
df['Percent; SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI) - Housing unit without a mortgage (excluding units where SMOCAPI cannot be computed) - 30.0 to 34.9 percent'].plot.hist(bins=20)

# %%
df['Percent; SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI) - Housing unit without a mortgage (excluding units where SMOCAPI cannot be computed) - 35.0 percent or more'].plot.hist(bins=20)

# %%
df['Percent; GROSS RENT - Occupied units paying rent - Less than $500'].plot.hist(bins=20)

# %%
df['Percent; GROSS RENT - Occupied units paying rent - $500 to $999'].plot.hist(bins=20)

# %%
df['Percent; GROSS RENT - Occupied units paying rent - $1,000 to $1,499'].plot.hist(bins=20)

# %%
df['Percent; GROSS RENT - Occupied units paying rent - $1,500 to $1,999'].plot.hist(bins=20)

# %%
df['Percent; GROSS RENT - Occupied units paying rent - $2,000 to $2,499'].plot.hist(bins=20)

# %%
df['Percent; GROSS RENT - Occupied units paying rent - $2,500 to $2,999'].plot.hist(bins=20)

# %%
df['Percent; GROSS RENT - Occupied units paying rent - $3,000 or more'].plot.hist(bins=20)

# %%
df['Percent; GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI) - Occupied units paying rent (excluding units where GRAPI cannot be computed) - Less than 15.0 percent'].plot.hist(bins=20)

# %%
df['Percent; GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI) - Occupied units paying rent (excluding units where GRAPI cannot be computed) - 15.0 to 19.9 percent'].plot.hist(bins=20)

# %%
df['Percent; GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI) - Occupied units paying rent (excluding units where GRAPI cannot be computed) - 20.0 to 24.9 percent'].plot.hist(bins=20)

# %%
df['Percent; GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI) - Occupied units paying rent (excluding units where GRAPI cannot be computed) - 25.0 to 29.9 percent'].plot.hist(bins=20)

# %%
df['Percent; GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI) - Occupied units paying rent (excluding units where GRAPI cannot be computed) - 30.0 to 34.9 percent'].plot.hist(bins=20)

# %%
df['Percent; GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI) - Occupied units paying rent (excluding units where GRAPI cannot be computed) - 35.0 percent or more'].plot.hist(bins=20)

# %%
df['Percent; SEX AND AGE - Total population - Male'].plot.hist(bins=20)

# %%
df['Percent; SEX AND AGE - Total population - Female'].plot.hist(bins=20)

# %%
df['Percent; SEX AND AGE - Under 5 years'].plot.hist(bins=20)

# %%
df['Percent; SEX AND AGE - 5 to 9 years'].plot.hist(bins=20)

# %%
df['Percent; SEX AND AGE - 10 to 14 years'].plot.hist(bins=20)

# %%
df['Percent; SEX AND AGE - 15 to 19 years'].plot.hist(bins=20)

# %%
df['Percent; SEX AND AGE - 20 to 24 years'].plot.hist(bins=20)

# %%
df['Percent; SEX AND AGE - 25 to 34 years'].plot.hist(bins=20)

# %%
df['Percent; SEX AND AGE - 35 to 44 years'].plot.hist(bins=20)

# %%
df['Percent; SEX AND AGE - 45 to 54 years'].plot.hist(bins=20)

# %%
df['Percent; SEX AND AGE - 55 to 59 years'].plot.hist(bins=20)

# %%
df['Percent; SEX AND AGE - 60 to 64 years'].plot.hist(bins=20)

# %%
df['Percent; SEX AND AGE - 65 to 74 years'].plot.hist(bins=20)

# %%
df['Percent; SEX AND AGE - 75 to 84 years'].plot.hist(bins=20)

# %%
df['Percent; SEX AND AGE - 85 years and over'].plot.hist(bins=20)

# %%
df['Percent; SEX AND AGE - 18 years and over'].plot.hist(bins=20)

# %%
df['Percent; SEX AND AGE - 21 years and over'].plot.hist(bins=20)

# %%
df['Percent; SEX AND AGE - 62 years and over'].plot.hist(bins=20)

# %%
df['Percent; SEX AND AGE - 65 years and over'].plot.hist(bins=20)

# %%
df['Percent; SEX AND AGE - 18 years and over - Male'].plot.hist(bins=20)

# %%
df['Percent; SEX AND AGE - 18 years and over - Female'].plot.hist(bins=20)

# %%
df['Percent; SEX AND AGE - 65 years and over - Male'].plot.hist(bins=20)

# %%
df['Percent; SEX AND AGE - 65 years and over - Female'].plot.hist(bins=20)
